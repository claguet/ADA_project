# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Reindex the votation tables to the canton identifiers

# %%
votations=pd.read_excel('Tables/Votation/all_votations.xlsx',sheetname='Sheet1',header=[0,1])

# %%
new_index=['ZH',
 'BE',
 'LU',
 'UR',
 'SZ',
 'OW',
 'NW',
 'GL',
 'ZG',
 'FR',
 'SO',
 'BS',
 'BL',
 'SH',
 'AR',
 'AI',
 'SG',
 'GR',
 'AG',
 'TG',
 'TI',
 'VD',
 'VS',
 'NE',
 'GE',
 'JU',
 'Switzerland']

# %%
for votation in [554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600, 601, 602, 603, 604]:
    votations[votation]['Canton']=new_index
# Out:
# /Users/lugrinclaire/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
votations
# Out:
#             554                                                          \
#          Canton  Electeurs    Votants % Particip.        Oui        Non
# 0            ZH    873'069    427'317      48.94%    214'164    210'976
# 1            BE    710'987    376'365      52.94%    152'348    221'611
# 2            LU    257'570    129'362      50.22%     51'306     76'713
# 3            UR     26'034     11'344      43.57%      3'300      7'929
# 4            SZ     97'849     50'166      51.27%     14'572     35'429
# 5            OW     25'117     13'548      53.94%      3'724      9'512
# 6            NW     30'265     15'908      52.56%      4'885     10'759
# 7            GL     25'991     10'837      41.70%      3'266      7'554
# 8            ZG     71'663     38'436      53.63%     16'403     21'913
# 9            FR    183'402     85'487      46.61%     34'847     49'851
# 10           SO    172'059     83'883      48.75%     29'204     54'161
# ...

# %%
writer = pd.ExcelWriter('Tables\\Votation\\all_votations_goodindex.xlsx')
votations.to_excel(writer,sheet_name = 'Sheet1') # table is stored in Sheet 1
writer.save()

# %%
# remove the % in the numbers : done with excel quickly
